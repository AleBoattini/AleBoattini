# %% [markdown]
# # Analisis de voz en audios de WhatsApp
# El notebook a continuacion detalla el trabajo realizado para poder identificar personas a travez de la voz, logrando un Accuracy del 98% con un modelo de red neuronal CNN.
#
# El entrenamiento se llevo a cabo con 6 personas (3 mujeres y 3 hombres) y 60 audios, obtenidos de la aplicacion de WhatsApp, los audios no tienen mayor tratamiento que el cambio de formato de .ogg a .wav y fragmentado en tiempos de 5 seg. Este tiempo fue tomado de esta forma por practicidad para obtener una muestra trabajable de datos y por recomendacion de un paper.

# %% [markdown]
# El metodo no es de mi autoria, las metricas empleadas para poder analisar los audios se desconocen que representan dado que para los fines practicos es suficiente con saber que existen y pueden usarse.

# %% [markdown]
# # Librerias a Utilizar
#
# Se Intento mantener las inicio todas las importaciones necesarias para poder trabajar el notebook, hay liberias que estan "comentadas" porque en Google Colab no necesitan instalacion previa. Si en entornos locales.

# %%
# Desinstalamos este apartado que genera problemas con pyaudio
# !apt install libasound2-dev portaudio19-dev libportaudio2 libportaudiocpp0 ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libasound2-dev is already the newest version (1.2.6.1-1ubuntu1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# Suggested packages:
#   portaudio19-doc
# The following NEW packages will be installed:
#   libportaudio2 libportaudiocpp0 portaudio19-dev
# 0 upgraded, 3 newly installed, 0 to remove and 16 not upgraded.
# Need to get 188 kB of archives.
# After this operation, 927 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libportaudio2 amd64 19.6.0-1.1 [65.3 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libportaudiocpp0 amd64 19.6.0-1.1 [16.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 portaudio19-dev amd64 19.6.0-1.1 [106 kB]
# Fetched 188 kB in 0s (1,725 kB/s)
# Selecting previously unselected package libportaudio2:amd64.
# (Reading database ... 120903 files and directories currently installed.)
# Preparing to unpack .../libportaudio2_19.6.0-1.1_amd64.deb ...
# Unpacking libportaudio2:amd64 (19.6.0-1.1) ...
# Selecting previously unselected package libportaudiocpp0:amd64.
# Preparing to unpack .../libportaudiocpp0_19.6.0-1.1_amd64.deb ...
# Unpacking libportaudiocpp0:amd64 (19.6.0-1.1) ...
# Selecting previously unselected package portaudio19-dev:amd64.
# Preparing to unpack .../portaudio19-dev_19.6.0-1.1_amd64.deb ...
# Unpacking portaudio19-dev:amd64 (19.6.0-1.1) ...
# Setting up libportaudio2:amd64 (19.6.0-1.1) ...
# Setting up libportaudiocpp0:amd64 (19.6.0-1.1) ...
# Setting up portaudio19-dev:amd64 (19.6.0-1.1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link

# %%
# !pip install pyaudio               # Para grabar y reproducir audio
# !pip install librosa               # Para análisis de audio y música
# !pip install SpeechRecognition     # Para reconocimiento de voz
# !pip install numpy                 # Para operaciones numéricas con matrices
# !pip install matplotlib            # Para visualizaciones y gráficos
# !pip install pandas                # Para manipulación y análisis de datos
# !pip install scikit-learn          # Para algoritmos de aprendizaje automático y modelado
# !pip install tensorflow            # Para aprendizaje profundo y redes neuronales
# !pip install scikeras
# Out:
# Collecting pyaudio
#   Downloading PyAudio-0.2.14.tar.gz (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 222.0 kB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pyaudio
#   Building wheel for pyaudio (pyproject.toml) ... done
#   Created wheel for pyaudio: filename=PyAudio-0.2.14-cp310-cp310-linux_x86_64.whl size=63859 sha256=5f15d553503f6af89f781780fe2e94da3156572147ad4ddf638ef2a10a35470c
#   Stored in directory: /root/.cache/pip/wheels/d6/21/f4/0b51d41ba79e51b16295cbb096ec49f334792814d545b508c5
# Successfully built pyaudio
# Installing collected packages: pyaudio
# Successfully installed pyaudio-0.2.14
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.23.5)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.5.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.0.7)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (4.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (23.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.11.17)
# Collecting SpeechRecognition
#   Downloading SpeechRecognition-3.10.1-py2.py3-none-any.whl (32.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 36.4 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from SpeechRecognition) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (2023.11.17)
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.10.1
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.59.3)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)
# Collecting scikeras
#   Downloading scikeras-0.12.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras) (23.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (3.2.0)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.12.0

# %%
# Importaciones estándar de Python
import os
import glob
import io
from datetime import datetime
import time
import random

# Audio y procesamiento de señales
import pyaudio
import librosa
import librosa.display
import speech_recognition as sr

# Visualizaciones
import matplotlib.pyplot as plt

# Análisis y manipulación de datos
import pandas as pd
import numpy as np

# Machine Learning y preprocesamiento
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder, normalize
from sklearn import metrics

# Deep Learning con Keras y TensorFlow
import sklearn as sklearn
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Convolution2D, MaxPooling2D, Activation, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from scikeras.wrappers import KerasRegressor
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, Callback
from tensorflow.keras import regularizers

# %%
# Evitamos la numeracion cientifica en los datos
np.set_printoptions(suppress=True)

# %% [markdown]
# # Preparacion de Datos

# %% [markdown]
# Tenemos segmentado con anterioridad los datos para Entrenamiento, Validacion y Test, que para poder trabajarlos se crea un DF guia que tendra como caracteristicas contar con el id del audio, la persona, y la direccion de la carpeta local, para ello primero se debe explorar los directorios y ver que contienen.

# %%
# Funcion que sirve para recorrer directorios de carpeta
def explora_dir(directory_name):
    '''
    Acepta el nombre de directorio como argumento e imprime el contenido de cada directorio secuencialmente.
    Imprime los subdirectorios y el número de imágenes presentes en cada uno.
    '''
    for dirpaths, dirnames, filenames in os.walk(directory_name):
        print(f"Existen {len(dirnames)} directorios y {len(filenames)} audios en '{dirpaths}'")

# %%
dir_Train='/content/drive/MyDrive/Audios/Train'
explora_dir(dir_Train)
# Out:
# Existen 6 directorios y 0 audios en '/content/drive/MyDrive/Audios/Train'
# Existen 0 directorios y 10 audios en '/content/drive/MyDrive/Audios/Train/Ari'
# Existen 0 directorios y 10 audios en '/content/drive/MyDrive/Audios/Train/Elias'
# Existen 0 directorios y 10 audios en '/content/drive/MyDrive/Audios/Train/Bel'
# Existen 0 directorios y 10 audios en '/content/drive/MyDrive/Audios/Train/Cel'
# Existen 0 directorios y 10 audios en '/content/drive/MyDrive/Audios/Train/Mica'
# Existen 0 directorios y 10 audios en '/content/drive/MyDrive/Audios/Train/Fran'

# %%
dir_Test='/content/drive/MyDrive/Audios/Test'
explora_dir(dir_Test)
# Out:
# Existen 6 directorios y 0 audios en '/content/drive/MyDrive/Audios/Test'
# Existen 0 directorios y 10 audios en '/content/drive/MyDrive/Audios/Test/Cel'
# Existen 0 directorios y 10 audios en '/content/drive/MyDrive/Audios/Test/Ari'
# Existen 0 directorios y 10 audios en '/content/drive/MyDrive/Audios/Test/Elias'
# Existen 0 directorios y 10 audios en '/content/drive/MyDrive/Audios/Test/Mica'
# Existen 0 directorios y 10 audios en '/content/drive/MyDrive/Audios/Test/Fran'
# Existen 0 directorios y 10 audios en '/content/drive/MyDrive/Audios/Test/Bel'

# %%
dir_Val='/content/drive/MyDrive/Audios/Val'
explora_dir(dir_Val)
# Out:
# Existen 6 directorios y 0 audios en '/content/drive/MyDrive/Audios/Val'
# Existen 0 directorios y 10 audios en '/content/drive/MyDrive/Audios/Val/Eli'
# Existen 0 directorios y 10 audios en '/content/drive/MyDrive/Audios/Val/Ari'
# Existen 0 directorios y 10 audios en '/content/drive/MyDrive/Audios/Val/Mic'
# Existen 0 directorios y 9 audios en '/content/drive/MyDrive/Audios/Val/Cel'
# Existen 0 directorios y 10 audios en '/content/drive/MyDrive/Audios/Val/Fran'
# Existen 0 directorios y 6 audios en '/content/drive/MyDrive/Audios/Val/Bel'

# %%
# Funcion que sirve para crear un df guia

def crear_df_del_directorio(dir_base):
    datos = {'id_audio': [], 'Persona': [], 'file_path': []}

    for root, dirs, files in os.walk(dir_base):
        for file in files:
            id_audio = file
            persona = os.path.basename(root)
            direccion = os.path.join(dir_base, persona, str(id_audio))

            datos['id_audio'].append(id_audio)
            datos['Persona'].append(persona)
            datos['file_path'].append(direccion)
    df = pd.DataFrame(datos)
    return df

# %%
# Creamos los dataframe guias para el entrenamiento como para el test
df_train= crear_df_del_directorio(dir_Train)
df_test=  crear_df_del_directorio(dir_Test)
df_val= crear_df_del_directorio(dir_Val)


# Muestra el DataFrame resultante
df_train.head()
# Out:
#       id_audio Persona                                          file_path
# 0  ar (10).wav     Ari  /content/drive/MyDrive/Audios/Train/Ari/ar (10...
# 1  ar (25).wav     Ari  /content/drive/MyDrive/Audios/Train/Ari/ar (25...
# 2   ar (1).wav     Ari  /content/drive/MyDrive/Audios/Train/Ari/ar (1)...
# 3   ar (4).wav     Ari  /content/drive/MyDrive/Audios/Train/Ari/ar (4)...
# 4  ar (13).wav     Ari  /content/drive/MyDrive/Audios/Train/Ari/ar (13...

# %% [markdown]
# ## Verificacion del Audio
# Un audio se puede observar, no solo escuchar, por lo que en este caso comprobamos que tenemos audios en los directorios tomando un archivo aleatorio y graficando su longitud de onda.

# %%
# Captura un indice aleatorio
i = random.choice(df_train.index)

# Selecciono el id de la fila
audio_name = df_train.id_audio[i]
persona=df_train.Persona[i]

# Creo la ruta del audio
path = os.path.join(dir_Train, persona, str(audio_name))

# Persona dueña del audio
print('Class: ', df_train.Persona[i])

# Carga el archivo en un formato serie de tiempo [x] y almacena el sample rate en [sr]
x, sr = librosa.load(path)

# Imprime la serie de tiempo en un grafico de amplitud de onda
plt.figure(figsize=(12, 4))
librosa.display.waveshow(x, sr=sr)
plt.title('Amplitud de la onda de audio')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.show()
# Out:
# Class:  Fran

# %% [markdown]
# ## Calculo de Metricas Principales de Audios
# Esta parte es particularmente compleja, no en codigo, si no en comprension. Los audios son caracterizados por muchas variables espaciales. Que quizas un ingeniero en sonidos las conozca a la perfeccion, en nuestra caso, obtenemos todas las conocidas sin descriminar ninguna.

# %%
# Creamos una funcion para extraer las mediciones del audio.
def extract_features(files):

    # Establece el nombre de la ruta a donde están los archivos de audio en mi computadora
    persona=files.Persona
    audio_name=files.id_audio

    file_name = files.file_path

    # Carga el archivo de audio como una serie de tiempo de coma flotante y asigna la frecuencia de muestreo predeterminada
    # Sample rate is set to 22050 by default
    # la serie de tiempo esta almacenada en [X]
    X, sample_rate = librosa.load(file_name)

    # genera Mel-frequency cepstral coefficients (MFCCs) de la serie de tiempo
    mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)

    # Genera una transformada de Fourier a corto plazo (STFT) para usar en chroma_stft

    stft = np.abs(librosa.stft(X))

    # Calcula un cromagrama a partir de una forma de onda o espectrograma de potencia.

    chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)

    # Calcula un espectograma de mel-scaled

    mel = np.mean(librosa.feature.melspectrogram(y=X, sr=sample_rate).T, axis=0)

    # Calcula el contraste espectral

    contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)

    # Calcula las características del centroide tonal (tonnetz)

    tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X),sr=sample_rate).T,axis=0)

    # Agregamos también las clases de cada archivo como una etiqueta al final

    label = files.Persona

    # Pedimos que nos devuelva todos los indicadores mas el target

    return mfccs, chroma, mel, contrast, tonnetz, label

# %% [markdown]
# Aplicamos la funcion a cada fila de nuestro dataframe guia, de esta forma nos devolvera una biblioteca que contendra 6 arrays por fila (audio)

# %%
# Obtenemos las caracteristicas de cada audio y medimos el tiempo de demora de la consulta

startTime = time.time()

features_train = df_train.apply(extract_features, axis=1)
features_test = df_test.apply(extract_features, axis=1)

finishTime = time.time()

# %%
print('Para procesar ', df_train.shape[0], 'audios llevo un \n'
    'tiempo de Consulta de ',finishTime-startTime, ' seg')
# Out:
# Para procesar  60 audios llevo un
# tiempo de Consulta de  120.39668869972229  seg

# %%
# De la lista generada construimos un array de datos, el cual ingresará a nuestra red neronal

X_train = []

for i in range(0, len(df_train)):

    X_train.append(np.concatenate((features_train[i][0], features_train[i][1],

                features_train[i][2], features_train[i][3],

                features_train[i][4]), axis=0))

X_test = []

for i in range(0, len(df_test)):

    X_test.append(np.concatenate((features_test[i][0], features_test[i][1],

                features_test[i][2], features_test[i][3],

                features_test[i][4]), axis=0))

# %%
# Cantidad de categorias a predecir, esta variable la ocuparemos seguidos por lo que la definimos aca arriba
Categorias=len(df_train.Persona.unique())

# %% [markdown]
# Para evitar complicacions futuras con los formatos, se le indico a todas las variables X e y que son array. En esta parte del codigo definimos las de entrenamiento y test, aprovechando que entre los features y los dataframe tienen el mismo orden de filas. Asumiendo que no se cruzaran los datos

# %%
y=np.array(df_train.Persona.unique())

y_train=np.array(df_train['Persona'])
y_test=np.array(df_test['Persona'])

# recodificamos el valor Y a un tipo categórico
lb = LabelEncoder()
lb.fit(y)

y_train = to_categorical(lb.transform(y_train),Categorias)
y_test = to_categorical(lb.transform(y_test),Categorias)

# Se deben convertir las variables en Numpy Array para ingregar al modelo de CNN
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)

# Normalizamos la variable X
X_train = normalize(X_train,norm='l2')
X_test = normalize(X_test,norm='l2')

# %% [markdown]
# # Modelo de Red Neuronal
# Como las metricas de audio son datos espaciales se opto por trabajar con Red Neuronal CNN, que es recomendada para empezar en este tipo de analisis.

# %% [markdown]
# ## Construccion del modelo
# No hay mucho por comentar aca, se probaron varias alternativas y parece que la sencilla siempre es la mas funcional.

# %%
neuronas=len(X_train[0])

print('La cantidad de neuronas a elegir sera igual al tamaño del array de la variable metrica, que es un conjunto de indicadores claves de audio: \n', neuronas)
# Out:
# La cantidad de neuronas a elegir sera igual al tamaño del array de la variable metrica, que es un conjunto de indicadores claves de audio:
#  193

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

# Crear un modelo secuencial
model = Sequential()

# Etapa 1: Capa de entrada con 193 neuronas y activación 'relu'
model.add(Dense(neuronas, input_shape=(193,), activation='relu'))

# Etapa 2: Aplicar Dropout para prevenir sobreajuste
model.add(Dropout(0.1))

# Etapa 3: Capa oculta con 128 neuronas y activación 'relu'
model.add(Dense(128, activation='relu'))

# Etapa 4: Aplicar Dropout nuevamente
model.add(Dropout(0.25))

# Etapa 5: Otra capa oculta con 128 neuronas y activación 'relu'
model.add(Dense(128, activation='relu'))

# Etapa 6: Aplicar Dropout de manera más agresiva
model.add(Dropout(0.5))

# Etapa 7: Capa de salida con 4 neuronas (categorías) y activación 'softmax'
model.add(Dense(Categorias, activation='softmax'))  # Número de categorías a predecir

# Compilar el modelo con función de pérdida 'categorical_crossentropy',
# métricas de 'accuracy' y optimizador 'adam'
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 193)               37442
#
#  dropout_6 (Dropout)         (None, 193)               0
#
#  dense_9 (Dense)             (None, 128)               24832
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 128)               16512
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 79560 (310.78 KB)
# Trainable params: 79560 (310.78 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Funciones
#
# Funciones implementadas para evitar el sobre ajuste al momento de entrenar, esto es importante modificar segun los datos de entrenamiento. La primera vez recomiendo no usarlas o pueden no obtener los resultados esperados.

# %% [markdown]
# ### Parada automatica

# %%
# Función para configurar el guardado de los pesos a medida que se va entrenando, muy útil cuando el procesamiento es largo y se puede perder por desconexión
def create_model_check_point_callback(checkpoint_path, monitor='val_loss'):
    """
    Toma el camino donde guardar los mejores pesos modelo obtenidos durante el entrenamiento.
    """
    # Crea un callback para guardar los pesos del modelo durante el entrenamiento
    model_checkpoint_cb = tf.keras.Callbacks.ModelCheckpoint(
        monitor=monitor,  # Elige la métrica a monitorear (por defecto, la pérdida en el conjunto de validación)
        filepath=checkpoint_path,  # Ruta donde se guardarán los pesos del modelo
        save_best_only=True,  # Guarda solo los pesos del modelo si la métrica monitorizada mejora
        save_weights_only=True,  # Guarda solo los pesos del modelo en lugar del modelo completo
        save_freq='epoch',  # Guarda los pesos al final de cada época
        verbose=1  # Muestra mensajes detallados durante el proceso de guardado
    )
    return model_checkpoint_cb  # Devuelve el callback configurado

# %%
# Criterio de parada extra, épocas que espera sin mejorar para detener entrenamiento
''' from tensorflow.keras.callbacks import EarlyStopping '''

earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='auto')

# Crea un objeto ReduceLROnPlateau, un callback que ajusta la tasa de aprendizaje durante el entrenamiento si la mejora en la métrica se estanca.
learning_rate_reduction = ReduceLROnPlateau(
    monitor='val_loss',  # Métrica a monitorear, en este caso, la pérdida en el conjunto de validación.
    patience=5,  # Número de épocas sin mejora después del cual la tasa de aprendizaje se reducirá.
    verbose=1  # Muestra mensajes detallados durante el proceso de ajuste de la tasa de aprendizaje.
)

# %% [markdown]
# ## Entrenamiento

# %%
# Entrenamiento del modelo con el conjunto de datos de entrenamiento (X_train).
# Se especifica el número de épocas (epochs) como 50, tamaño del lote (batch_size) como 300,
# conjunto de datos de validación (test_data) para evaluar el rendimiento en datos no vistos durante el entrenamiento.
# Se utiliza la lista de callbacks [earlystop, learning_rate_reduction, ModelCheckPoint_model_cb]
# para aplicar acciones específicas durante el entrenamiento (por ejemplo, detener el entrenamiento temprano, ajustar la tasa de aprendizaje, guardar los mejores pesos).
history = model.fit(X_train,
                    y_train,
                    batch_size=256,
                    epochs=300,
                    validation_data=(X_test, y_test),
                    callbacks=[earlystop, learning_rate_reduction] # En este punto pueden quitar las funciones en su primera corrida para evitar interrupciones equivocadas
                    )
# Out:
# Epoch 1/300
# 1/1 [==============================] - 1s 1s/step - loss: 1.7991 - accuracy: 0.1500 - val_loss: 1.7924 - val_accuracy: 0.1500 - lr: 0.0010
# Epoch 2/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.7927 - accuracy: 0.2167 - val_loss: 1.7909 - val_accuracy: 0.2167 - lr: 0.0010
# Epoch 3/300
# 1/1 [==============================] - 0s 33ms/step - loss: 1.7923 - accuracy: 0.2000 - val_loss: 1.7892 - val_accuracy: 0.2167 - lr: 0.0010
# Epoch 4/300
# 1/1 [==============================] - 0s 32ms/step - loss: 1.7936 - accuracy: 0.2167 - val_loss: 1.7873 - val_accuracy: 0.2167 - lr: 0.0010
# Epoch 5/300
# 1/1 [==============================] - 0s 32ms/step - loss: 1.7924 - accuracy: 0.1667 - val_loss: 1.7855 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 6/300
# 1/1 [==============================] - 0s 32ms/step - loss: 1.7746 - accuracy: 0.2500 - val_loss: 1.7836 - val_accuracy: 0.2500 - lr: 0.0010
# Epoch 7/300
# 1/1 [==============================] - 0s 33ms/step - loss: 1.8014 - accuracy: 0.1167 - val_loss: 1.7817 - val_accuracy: 0.2833 - lr: 0.0010
# Epoch 8/300
# 1/1 [==============================] - 0s 32ms/step - loss: 1.7869 - accuracy: 0.2000 - val_loss: 1.7801 - val_accuracy: 0.3000 - lr: 0.0010
# Epoch 9/300
# 1/1 [==============================] - 0s 31ms/step - loss: 1.7959 - accuracy: 0.1500 - val_loss: 1.7784 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 10/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.7840 - accuracy: 0.2500 - val_loss: 1.7762 - val_accuracy: 0.3500 - lr: 0.0010
# Epoch 11/300
# 1/1 [==============================] - 0s 38ms/step - loss: 1.7816 - accuracy: 0.2333 - val_loss: 1.7741 - val_accuracy: 0.4833 - lr: 0.0010
# Epoch 12/300
# 1/1 [==============================] - 0s 34ms/step - loss: 1.7708 - accuracy: 0.3333 - val_loss: 1.7717 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 13/300
# 1/1 [==============================] - 0s 32ms/step - loss: 1.7809 - accuracy: 0.2500 - val_loss: 1.7691 - val_accuracy: 0.5167 - lr: 0.0010
# Epoch 14/300
# 1/1 [==============================] - 0s 63ms/step - loss: 1.7761 - accuracy: 0.2333 - val_loss: 1.7666 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 15/300
# 1/1 [==============================] - 0s 35ms/step - loss: 1.7601 - accuracy: 0.3667 - val_loss: 1.7639 - val_accuracy: 0.5167 - lr: 0.0010
# Epoch 16/300
# 1/1 [==============================] - 0s 35ms/step - loss: 1.7645 - accuracy: 0.4000 - val_loss: 1.7611 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 17/300
# 1/1 [==============================] - 0s 33ms/step - loss: 1.7682 - accuracy: 0.2500 - val_loss: 1.7584 - val_accuracy: 0.5667 - lr: 0.0010
# Epoch 18/300
# 1/1 [==============================] - 0s 35ms/step - loss: 1.7612 - accuracy: 0.2833 - val_loss: 1.7556 - val_accuracy: 0.5500 - lr: 0.0010
# Epoch 19/300
# 1/1 [==============================] - 0s 45ms/step - loss: 1.7751 - accuracy: 0.3167 - val_loss: 1.7526 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 20/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.7517 - accuracy: 0.4500 - val_loss: 1.7491 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 21/300
# 1/1 [==============================] - 0s 33ms/step - loss: 1.7629 - accuracy: 0.2833 - val_loss: 1.7454 - val_accuracy: 0.5167 - lr: 0.0010
# Epoch 22/300
# 1/1 [==============================] - 0s 32ms/step - loss: 1.7543 - accuracy: 0.2333 - val_loss: 1.7413 - val_accuracy: 0.5167 - lr: 0.0010
# Epoch 23/300
# 1/1 [==============================] - 0s 31ms/step - loss: 1.7387 - accuracy: 0.4167 - val_loss: 1.7368 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 24/300
# 1/1 [==============================] - 0s 33ms/step - loss: 1.7390 - accuracy: 0.4500 - val_loss: 1.7314 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 25/300
# 1/1 [==============================] - 0s 33ms/step - loss: 1.7298 - accuracy: 0.3833 - val_loss: 1.7258 - val_accuracy: 0.5167 - lr: 0.0010
# Epoch 26/300
# 1/1 [==============================] - 0s 32ms/step - loss: 1.7441 - accuracy: 0.3333 - val_loss: 1.7198 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 27/300
# 1/1 [==============================] - 0s 32ms/step - loss: 1.7400 - accuracy: 0.2833 - val_loss: 1.7134 - val_accuracy: 0.5500 - lr: 0.0010
# Epoch 28/300
# 1/1 [==============================] - 0s 32ms/step - loss: 1.7191 - accuracy: 0.4000 - val_loss: 1.7068 - val_accuracy: 0.5667 - lr: 0.0010
# Epoch 29/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.7209 - accuracy: 0.4167 - val_loss: 1.7000 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 30/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.7230 - accuracy: 0.4333 - val_loss: 1.6927 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 31/300
# 1/1 [==============================] - 0s 38ms/step - loss: 1.7009 - accuracy: 0.3333 - val_loss: 1.6847 - val_accuracy: 0.6333 - lr: 0.0010
# Epoch 32/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.7079 - accuracy: 0.4167 - val_loss: 1.6765 - val_accuracy: 0.6500 - lr: 0.0010
# Epoch 33/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.6871 - accuracy: 0.5500 - val_loss: 1.6676 - val_accuracy: 0.6500 - lr: 0.0010
# Epoch 34/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.6819 - accuracy: 0.4500 - val_loss: 1.6585 - val_accuracy: 0.6333 - lr: 0.0010
# Epoch 35/300
# 1/1 [==============================] - 0s 33ms/step - loss: 1.6537 - accuracy: 0.4833 - val_loss: 1.6484 - val_accuracy: 0.6167 - lr: 0.0010
# Epoch 36/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.6761 - accuracy: 0.4500 - val_loss: 1.6374 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 37/300
# 1/1 [==============================] - 0s 43ms/step - loss: 1.6700 - accuracy: 0.4000 - val_loss: 1.6256 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 38/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.6472 - accuracy: 0.4500 - val_loss: 1.6128 - val_accuracy: 0.5667 - lr: 0.0010
# Epoch 39/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.6090 - accuracy: 0.5833 - val_loss: 1.5991 - val_accuracy: 0.5667 - lr: 0.0010
# Epoch 40/300
# 1/1 [==============================] - 0s 35ms/step - loss: 1.6353 - accuracy: 0.3833 - val_loss: 1.5851 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 41/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.6144 - accuracy: 0.5333 - val_loss: 1.5706 - val_accuracy: 0.5667 - lr: 0.0010
# Epoch 42/300
# 1/1 [==============================] - 0s 33ms/step - loss: 1.5878 - accuracy: 0.4667 - val_loss: 1.5555 - val_accuracy: 0.5667 - lr: 0.0010
# Epoch 43/300
# 1/1 [==============================] - 0s 32ms/step - loss: 1.6137 - accuracy: 0.4000 - val_loss: 1.5399 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 44/300
# 1/1 [==============================] - 0s 38ms/step - loss: 1.5940 - accuracy: 0.4667 - val_loss: 1.5239 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 45/300
# 1/1 [==============================] - 0s 35ms/step - loss: 1.5633 - accuracy: 0.4667 - val_loss: 1.5071 - val_accuracy: 0.6167 - lr: 0.0010
# Epoch 46/300
# 1/1 [==============================] - 0s 35ms/step - loss: 1.5695 - accuracy: 0.4333 - val_loss: 1.4898 - val_accuracy: 0.6333 - lr: 0.0010
# Epoch 47/300
# 1/1 [==============================] - 0s 34ms/step - loss: 1.5604 - accuracy: 0.4500 - val_loss: 1.4722 - val_accuracy: 0.6333 - lr: 0.0010
# Epoch 48/300
# 1/1 [==============================] - 0s 35ms/step - loss: 1.5128 - accuracy: 0.6167 - val_loss: 1.4535 - val_accuracy: 0.6333 - lr: 0.0010
# Epoch 49/300
# 1/1 [==============================] - 0s 34ms/step - loss: 1.5067 - accuracy: 0.4667 - val_loss: 1.4350 - val_accuracy: 0.6167 - lr: 0.0010
# Epoch 50/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.4785 - accuracy: 0.4167 - val_loss: 1.4167 - val_accuracy: 0.6333 - lr: 0.0010
# Epoch 51/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.4014 - accuracy: 0.6000 - val_loss: 1.3978 - val_accuracy: 0.6333 - lr: 0.0010
# Epoch 52/300
# 1/1 [==============================] - 0s 34ms/step - loss: 1.4409 - accuracy: 0.4500 - val_loss: 1.3783 - val_accuracy: 0.6167 - lr: 0.0010
# Epoch 53/300
# 1/1 [==============================] - 0s 33ms/step - loss: 1.4294 - accuracy: 0.5333 - val_loss: 1.3575 - val_accuracy: 0.6500 - lr: 0.0010
# Epoch 54/300
# 1/1 [==============================] - 0s 35ms/step - loss: 1.4239 - accuracy: 0.5333 - val_loss: 1.3345 - val_accuracy: 0.6833 - lr: 0.0010
# Epoch 55/300
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3553 - accuracy: 0.6167 - val_loss: 1.3115 - val_accuracy: 0.6833 - lr: 0.0010
# Epoch 56/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3456 - accuracy: 0.6167 - val_loss: 1.2877 - val_accuracy: 0.7167 - lr: 0.0010
# Epoch 57/300
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3762 - accuracy: 0.5333 - val_loss: 1.2636 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 58/300
# 1/1 [==============================] - 0s 34ms/step - loss: 1.3094 - accuracy: 0.5833 - val_loss: 1.2392 - val_accuracy: 0.7333 - lr: 0.0010
# Epoch 59/300
# 1/1 [==============================] - 0s 34ms/step - loss: 1.2904 - accuracy: 0.5833 - val_loss: 1.2164 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 60/300
# 1/1 [==============================] - 0s 32ms/step - loss: 1.3091 - accuracy: 0.5333 - val_loss: 1.1941 - val_accuracy: 0.7833 - lr: 0.0010
# Epoch 61/300
# 1/1 [==============================] - 0s 33ms/step - loss: 1.2326 - accuracy: 0.5833 - val_loss: 1.1712 - val_accuracy: 0.7833 - lr: 0.0010
# Epoch 62/300
# 1/1 [==============================] - 0s 58ms/step - loss: 1.1870 - accuracy: 0.6667 - val_loss: 1.1485 - val_accuracy: 0.7833 - lr: 0.0010
# Epoch 63/300
# 1/1 [==============================] - 0s 39ms/step - loss: 1.1975 - accuracy: 0.6500 - val_loss: 1.1267 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 64/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.1604 - accuracy: 0.5500 - val_loss: 1.1063 - val_accuracy: 0.7833 - lr: 0.0010
# Epoch 65/300
# 1/1 [==============================] - 0s 40ms/step - loss: 1.1895 - accuracy: 0.5500 - val_loss: 1.0852 - val_accuracy: 0.7833 - lr: 0.0010
# Epoch 66/300
# 1/1 [==============================] - 0s 34ms/step - loss: 1.1548 - accuracy: 0.5500 - val_loss: 1.0643 - val_accuracy: 0.8667 - lr: 0.0010
# Epoch 67/300
# 1/1 [==============================] - 0s 33ms/step - loss: 1.1063 - accuracy: 0.5833 - val_loss: 1.0462 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 68/300
# 1/1 [==============================] - 0s 32ms/step - loss: 1.0778 - accuracy: 0.6667 - val_loss: 1.0231 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 69/300
# 1/1 [==============================] - 0s 33ms/step - loss: 1.1288 - accuracy: 0.5667 - val_loss: 0.9968 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 70/300
# 1/1 [==============================] - 0s 34ms/step - loss: 0.9848 - accuracy: 0.6833 - val_loss: 0.9711 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 71/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.9779 - accuracy: 0.7333 - val_loss: 0.9497 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 72/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.9628 - accuracy: 0.7333 - val_loss: 0.9289 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 73/300
# 1/1 [==============================] - 0s 34ms/step - loss: 0.9890 - accuracy: 0.6333 - val_loss: 0.9082 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 74/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.9759 - accuracy: 0.7000 - val_loss: 0.8904 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 75/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.9178 - accuracy: 0.7000 - val_loss: 0.8759 - val_accuracy: 0.7833 - lr: 0.0010
# Epoch 76/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.9992 - accuracy: 0.6167 - val_loss: 0.8596 - val_accuracy: 0.7833 - lr: 0.0010
# Epoch 77/300
# 1/1 [==============================] - 0s 34ms/step - loss: 0.9310 - accuracy: 0.7000 - val_loss: 0.8423 - val_accuracy: 0.7833 - lr: 0.0010
# Epoch 78/300
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8951 - accuracy: 0.7500 - val_loss: 0.8182 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 79/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.8718 - accuracy: 0.7333 - val_loss: 0.7988 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 80/300
# 1/1 [==============================] - 0s 38ms/step - loss: 0.9135 - accuracy: 0.7333 - val_loss: 0.7835 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 81/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.8403 - accuracy: 0.7000 - val_loss: 0.7688 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 82/300
# 1/1 [==============================] - 0s 38ms/step - loss: 0.7497 - accuracy: 0.7667 - val_loss: 0.7539 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 83/300
# 1/1 [==============================] - 0s 34ms/step - loss: 0.8054 - accuracy: 0.7333 - val_loss: 0.7407 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 84/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.7515 - accuracy: 0.8000 - val_loss: 0.7281 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 85/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.7594 - accuracy: 0.7667 - val_loss: 0.7162 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 86/300
# 1/1 [==============================] - 0s 34ms/step - loss: 0.7558 - accuracy: 0.7667 - val_loss: 0.7038 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 87/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6707 - accuracy: 0.8667 - val_loss: 0.6907 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 88/300
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6352 - accuracy: 0.8833 - val_loss: 0.6765 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 89/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6465 - accuracy: 0.8500 - val_loss: 0.6632 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 90/300
# 1/1 [==============================] - 0s 53ms/step - loss: 0.7385 - accuracy: 0.7833 - val_loss: 0.6513 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 91/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6275 - accuracy: 0.8833 - val_loss: 0.6400 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 92/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.5751 - accuracy: 0.8500 - val_loss: 0.6296 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 93/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6964 - accuracy: 0.7833 - val_loss: 0.6193 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 94/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6391 - accuracy: 0.8000 - val_loss: 0.6085 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 95/300
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5760 - accuracy: 0.8500 - val_loss: 0.5985 - val_accuracy: 0.7833 - lr: 0.0010
# Epoch 96/300
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5658 - accuracy: 0.8167 - val_loss: 0.5900 - val_accuracy: 0.7833 - lr: 0.0010
# Epoch 97/300
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5784 - accuracy: 0.8500 - val_loss: 0.5791 - val_accuracy: 0.7833 - lr: 0.0010
# Epoch 98/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5047 - accuracy: 0.8833 - val_loss: 0.5670 - val_accuracy: 0.7833 - lr: 0.0010
# Epoch 99/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.5648 - accuracy: 0.8667 - val_loss: 0.5568 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 100/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5818 - accuracy: 0.8167 - val_loss: 0.5480 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 101/300
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4202 - accuracy: 0.8833 - val_loss: 0.5411 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 102/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4913 - accuracy: 0.8833 - val_loss: 0.5348 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 103/300
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5220 - accuracy: 0.8333 - val_loss: 0.5282 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 104/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4907 - accuracy: 0.8667 - val_loss: 0.5233 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 105/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5162 - accuracy: 0.8167 - val_loss: 0.5175 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 106/300
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4936 - accuracy: 0.9000 - val_loss: 0.5100 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 107/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4900 - accuracy: 0.9167 - val_loss: 0.5014 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 108/300
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4784 - accuracy: 0.8667 - val_loss: 0.4912 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 109/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4349 - accuracy: 0.8500 - val_loss: 0.4823 - val_accuracy: 0.8667 - lr: 0.0010
# Epoch 110/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3890 - accuracy: 0.9000 - val_loss: 0.4759 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 111/300
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3649 - accuracy: 0.9000 - val_loss: 0.4733 - val_accuracy: 0.8667 - lr: 0.0010
# Epoch 112/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4221 - accuracy: 0.9000 - val_loss: 0.4729 - val_accuracy: 0.8667 - lr: 0.0010
# Epoch 113/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4250 - accuracy: 0.9000 - val_loss: 0.4689 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 114/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4092 - accuracy: 0.8333 - val_loss: 0.4615 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 115/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3480 - accuracy: 0.8833 - val_loss: 0.4547 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 116/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3098 - accuracy: 0.9333 - val_loss: 0.4512 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 117/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3311 - accuracy: 0.9167 - val_loss: 0.4493 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 118/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4130 - accuracy: 0.8833 - val_loss: 0.4466 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 119/300
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2917 - accuracy: 0.9500 - val_loss: 0.4440 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 120/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2802 - accuracy: 0.9667 - val_loss: 0.4405 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 121/300
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3093 - accuracy: 0.9333 - val_loss: 0.4357 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 122/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3491 - accuracy: 0.8667 - val_loss: 0.4295 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 123/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2868 - accuracy: 0.9167 - val_loss: 0.4257 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 124/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2932 - accuracy: 0.9333 - val_loss: 0.4205 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 125/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2672 - accuracy: 0.9167 - val_loss: 0.4137 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 126/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3569 - accuracy: 0.9167 - val_loss: 0.4104 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 127/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2620 - accuracy: 0.9167 - val_loss: 0.4116 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 128/300
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2631 - accuracy: 0.9500 - val_loss: 0.4127 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 129/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2908 - accuracy: 0.9333 - val_loss: 0.4120 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 130/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.2537 - accuracy: 0.9500 - val_loss: 0.4111 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 131/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2485 - accuracy: 0.9500 - val_loss: 0.4069 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 132/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2742 - accuracy: 0.9000 - val_loss: 0.4058 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 133/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2297 - accuracy: 0.9500 - val_loss: 0.4075 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 134/300
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2482 - accuracy: 0.9500 - val_loss: 0.4101 - val_accuracy: 0.8667 - lr: 0.0010
# Epoch 135/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2432 - accuracy: 0.9333 - val_loss: 0.4094 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 136/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2636 - accuracy: 0.9667 - val_loss: 0.4093 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 137/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2752 - accuracy: 0.9167 - val_loss: 0.4036 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 138/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2240 - accuracy: 0.9500 - val_loss: 0.3970 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 139/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1745 - accuracy: 0.9667 - val_loss: 0.3913 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 140/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1950 - accuracy: 0.9667 - val_loss: 0.3873 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 141/300
# 1/1 [==============================] - 0s 39ms/step - loss: 0.2233 - accuracy: 0.9667 - val_loss: 0.3904 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 142/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2064 - accuracy: 0.9333 - val_loss: 0.3972 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 143/300
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2410 - accuracy: 0.9500 - val_loss: 0.3966 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 144/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1795 - accuracy: 0.9500 - val_loss: 0.3927 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 145/300
# 1/1 [==============================] - 0s 39ms/step - loss: 0.2303 - accuracy: 0.9333 - val_loss: 0.3872 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 146/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2342 - accuracy: 0.9500 - val_loss: 0.3860 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 147/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1925 - accuracy: 0.9500 - val_loss: 0.3853 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 148/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1620 - accuracy: 1.0000 - val_loss: 0.3891 - val_accuracy: 0.8667 - lr: 0.0010
# Epoch 149/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1209 - accuracy: 1.0000 - val_loss: 0.3942 - val_accuracy: 0.8833 - lr: 0.0010
# Epoch 150/300
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2074 - accuracy: 0.9500 - val_loss: 0.3930 - val_accuracy: 0.8833 - lr: 0.0010
# Epoch 151/300
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1772 - accuracy: 0.9500 - val_loss: 0.3894 - val_accuracy: 0.8833 - lr: 0.0010
# Epoch 152/300
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1903 - accuracy: 0.9500 - val_loss: 0.3808 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 153/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1174 - accuracy: 1.0000 - val_loss: 0.3782 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 154/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1366 - accuracy: 1.0000 - val_loss: 0.3793 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 155/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1482 - accuracy: 0.9667 - val_loss: 0.3815 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 156/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1788 - accuracy: 0.9667 - val_loss: 0.3846 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 157/300
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2311 - accuracy: 0.9833 - val_loss: 0.3787 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 158/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1174 - accuracy: 0.9833 - val_loss: 0.3707 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 159/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1352 - accuracy: 0.9833 - val_loss: 0.3618 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 160/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1744 - accuracy: 0.9667 - val_loss: 0.3563 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 161/300
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1348 - accuracy: 1.0000 - val_loss: 0.3534 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 162/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1256 - accuracy: 1.0000 - val_loss: 0.3529 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 163/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1493 - accuracy: 0.9833 - val_loss: 0.3545 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 164/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1578 - accuracy: 0.9833 - val_loss: 0.3566 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 165/300
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1314 - accuracy: 1.0000 - val_loss: 0.3582 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 166/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1590 - accuracy: 0.9333 - val_loss: 0.3550 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 167/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1125 - accuracy: 0.9667 - val_loss: 0.3521 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 168/300
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1112 - accuracy: 0.9833 - val_loss: 0.3508 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 169/300
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1066 - accuracy: 1.0000 - val_loss: 0.3513 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 170/300
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1443 - accuracy: 0.9667 - val_loss: 0.3550 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 171/300
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1281 - accuracy: 0.9833 - val_loss: 0.3573 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 172/300
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1005 - accuracy: 0.9833 - val_loss: 0.3582 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 173/300
# 1/1 [==============================] - ETA: 0s - loss: 0.0902 - accuracy: 0.9833
# Epoch 173: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0902 - accuracy: 0.9833 - val_loss: 0.3587 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 174/300
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1154 - accuracy: 0.9667 - val_loss: 0.3586 - val_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 175/300
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0593 - accuracy: 1.0000 - val_loss: 0.3586 - val_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 176/300
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0783 - accuracy: 1.0000 - val_loss: 0.3585 - val_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 177/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0883 - accuracy: 0.9833 - val_loss: 0.3583 - val_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 178/300
# 1/1 [==============================] - ETA: 0s - loss: 0.0954 - accuracy: 1.0000
# Epoch 178: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0954 - accuracy: 1.0000 - val_loss: 0.3583 - val_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 178: early stopping

# %%
# Esta funcion sirve para graficar 2 curvas que muestren como evolucionan 2 metricas
def plot_curves(history):
    '''
    Devuelve curvas de loss u accuracy, separadas para métricas de entrenamiento y validación.
    '''
    train_loss=history.history['loss']
    val_loss=history.history['val_loss']

    train_accuracy=history.history['accuracy']
    val_accuracy=history.history['val_accuracy']

    epochs=range(1,len(history.history['loss'])+1)
    plt.figure(figsize=(20,7))
    plt.subplot(1,2,1)
    plt.plot(epochs,train_loss,label="training_loss")
    plt.plot(epochs,val_loss,label="validation_loss")
    plt.title("Pérdida en el Entrenamiento")
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(epochs,train_accuracy,label="training_acc")
    plt.plot(epochs,val_accuracy,label="validation_acc")
    plt.title("Precisión en el Entrenamiento")
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

# %%
plot_curves(history)

# %% [markdown]
# El modelo corta antes del overfitting, por lo que estamos en la situacion ideal. A su vez que se estan obteniendo acurracys muy elevados.

# %% [markdown]
# # Observacion de las predicciones

# %%
def predict_class(y_pred):
    y_class = []
    for i in y_pred:
        y_class.append(int(np.where(i == np.amax(i))[0]))

    return np.array(y_class)

# %%
# Obtenemos nuestras predicciones de los datos de prueba

pred = model.predict(X_test)

pred_class = predict_class(pred)
real_class = lb.transform(np.array(df_test['Persona']))

pred_name = lb.inverse_transform(pred_class)
real_name=df_test['Persona']
# Out:
# 2/2 [==============================] - 0s 5ms/step

# %%
# Se crea un dataframe con información relacionada a las predicciones
pred_df=pd.DataFrame({
    'Path': df_test.id_audio,
    'y_true':real_class,
    'y_pred':pred_class,
    'pred_conf':pred.max(axis=1),
    'actual_class_name':real_name,
    'pred_class_name':pred_name
     })
pred_df.head(10)
# Out:
#           Path  y_true  y_pred  pred_conf actual_class_name pred_class_name
# 0   Ce (2).wav       2       2   0.900909               Cel             Cel
# 1  Ce (29).wav       2       3   0.782719               Cel           Elias
# 2  Ce (18).wav       2       2   0.994390               Cel             Cel
# 3  Ce (21).wav       2       2   0.997031               Cel             Cel
# 4  Ce (27).wav       2       3   0.839686               Cel           Elias
# 5  Ce (25).wav       2       2   0.592595               Cel             Cel
# 6   Ce (6).wav       2       2   0.998839               Cel             Cel
# 7  Ce (10).wav       2       2   0.996761               Cel             Cel
# 8  Ce (14).wav       2       2   0.999656               Cel             Cel
# 9  Ce (23).wav       2       2   0.997611               Cel             Cel

# %%
# Función para graficar como imagen la matriz de confusión
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def plot_confusion_matrix(y_true, y_preds, labels=None, model_name=None, normalize=None):
    """
    Función para graficar la Matrix de confusión
    y_true: vector de salida real
    y_predic: vector de salida predicho por el modelo
    labels: opcional, para nombrar las clases. Lista con strings
    model_name: opcional, para poner un título al gráfico
    normalize: {'true', 'pred', 'all'}, default=None
        Normalizes confusion matrix over the true (rows), predicted (columns)
        conditions or all the population. If None, confusion matrix will not be
        normalized.
    """
    if normalize:
        cm = confusion_matrix(y_true, y_preds, normalize=normalize)
    else:
        cm = confusion_matrix(y_true, y_preds)
    cmd = ConfusionMatrixDisplay(cm, display_labels=labels)
    cmd.plot()
    cmd.ax_.set(xlabel='Clase Predicha', ylabel='Clase Real')
    if model_name:
        cmd.ax_.set(title=model_name)

# %%
plot_confusion_matrix(pred_df['y_true'], pred_df['y_pred'],labels=lb.inverse_transform([0,1,2,3,4,5]), model_name="Red Neuronal", normalize='true')

# %% [markdown]
# Los audios no tienen 1 solo procesamiento ni de ruido, ni de escucha, hay fragmentos que posiblemente no sean audibles o no contengan mas de 1 segundo de voz. Esto es fue asi aproposito para agregar algo de robustes al modelo.

# %% [markdown]
# # Test
# Aca se encuentran un preprosecamiento de datos, sobre audios desconocidos para el modelo, asi poder devuelta analizar su precision y evaluar a su vez el tiempo de respuesta.

# %%
df_val.head()
# Out:
#       id_audio Persona                                          file_path
# 0  El (11).wav     Eli  /content/drive/MyDrive/Audios/Val/Eli/El (11).wav
# 1   El (9).wav     Eli   /content/drive/MyDrive/Audios/Val/Eli/El (9).wav
# 2  El (17).wav     Eli  /content/drive/MyDrive/Audios/Val/Eli/El (17).wav
# 3  El (13).wav     Eli  /content/drive/MyDrive/Audios/Val/Eli/El (13).wav
# 4  El (12).wav     Eli  /content/drive/MyDrive/Audios/Val/Eli/El (12).wav

# %%
# Captura un indice aleatorio
i = random.choice(df_val.index)

file_val=df_val.loc[i]
file_val
# Out:
# id_audio                                           Ce (8).wav
# Persona                                                   Cel
# file_path    /content/drive/MyDrive/Audios/Val/Cel/Ce (8).wav
# Name: 37, dtype: object

# %%
# Calculamos las features
ti=time.time()

features_val = extract_features(file_val)

X_val=[]

X_val.append(np.concatenate((features_val[0], features_val[1],

                    features_val[2], features_val[3],

                    features_val[4]), axis=0))

X_val = np.array(X_val)
X_val = normalize(X_val,norm='l2')


tm=time.time()
dif1=tm-ti
print('Tiempo de prepacion del audio: ', dif1)

# Obtenemos nuestras predicciones de los datos de prueba

pred = model.predict(X_val)

pred_class = predict_class(pred)
pred_name = lb.inverse_transform(pred_class)

tf=time.time()

print("\n La certeza con la que predice el resultado es de: ", pred.max())
print("\n La  prediccion del audio corresponde a: ", pred_name, 'Y la persona real es:', file_val.Persona)
print("\n Tiempo en total que le toma desde preparar el audio hasta realizar la prediccion: ", tf-ti, " seg")
# Out:
# Tiempo de prepacion del audio:  1.0063347816467285
# 1/1 [==============================] - 0s 37ms/step
#
#  La certeza con la que predice el resultado es de:  0.9867359
#
#  La  prediccion del audio corresponde a:  ['Cel'] Y la persona real es: Cel
#
#  Tiempo en total que le toma desde preparar el audio hasta realizar la prediccion:  1.1550319194793701  seg
